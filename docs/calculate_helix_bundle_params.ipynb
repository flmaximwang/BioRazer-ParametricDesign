# %%
from biorazer_parametric_design.models.helix import CCCPHelixBundle


bundle = CCCPHelixBundle.from_param(
    2,
    chain_num=2,
    aa_num=14,
    r1=5.07,
    w1=100 * np.pi / 180,
    phi1=280 * np.pi / 180,
    a=-12 * np.pi / 180,
    x1=7.01,
    w0=-2.45 * np.pi / 180,
    alpha=17.5 * np.pi / 180,
    z_off=0,
    z=1,
    y_prototype=np.array([0, 1, 0]),
)
